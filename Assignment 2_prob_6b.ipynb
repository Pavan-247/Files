# %% [markdown]
# <a href="https://colab.research.google.com/github/Pavan-247/Files/blob/main/Assignment%202_prob_6b.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns; sns.set()
import numpy as np
from sklearn import datasets
from sklearn.decomposition import PCA
import numpy as np

plt.style.use('classic')
# %matplotlib inline

# %%
#from google.colab import files
#uploaded = files.upload()
# Out:
#      <input type="file" id="files-85cf6330-3e8a-4ee7-ba15-0ca022c1f257" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-85cf6330-3e8a-4ee7-ba15-0ca022c1f257">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Boston_Building_Energy_Data_Ex_5p3 (1).xlsx to Boston_Building_Energy_Data_Ex_5p3 (1).xlsx

# %%
import requests as rq
from io import BytesIO


url = "https://github.com/Pavan-247/Files/blob/main/Boston_Building_Energy_Data_Ex_5p3%20(1).xlsx?raw=true"
data = rq.get(url).content
d = pd.read_excel(BytesIO(data))
d
# Out:
#     Case                             PropertyType  FloorArea_ft_2  YearBuilt  \
# 0      1                         'Medical Office'           35036       1990
# 1      2                                 'Office'           36865       1981
# 2      3  'Hospital (General Medical & Surgical)'          865000       2008
# 3      4                                  'Other'          291451       2010
# 4      5                    'Multifamily Housing'            9568       1986
# 5      6                         'Medical Office'          230000       1950
# 6      7  'Hospital (General Medical & Surgical)'         2497517       1975
# 7      8                                 'Office'           65016       1913
# 8      9                    'Multifamily Housing'           25000       1891
# 9     10                                 'Office'          180096       1920
# 10    11              'Supermarket/Grocery Store'           18175       1978
# ...

# %%
#import io
#d = pd.read_excel(io.BytesIO(uploaded['Boston_Building_Energy_Data_Ex_5p3 (1).xlsx']))
#d
# Out:
#     Case                             PropertyType  FloorArea_ft_2  YearBuilt  \
# 0      1                         'Medical Office'           35036       1990
# 1      2                                 'Office'           36865       1981
# 2      3  'Hospital (General Medical & Surgical)'          865000       2008
# 3      4                                  'Other'          291451       2010
# 4      5                    'Multifamily Housing'            9568       1986
# 5      6                         'Medical Office'          230000       1950
# 6      7  'Hospital (General Medical & Surgical)'         2497517       1975
# 7      8                                 'Office'           65016       1913
# 8      9                    'Multifamily Housing'           25000       1891
# 9     10                                 'Office'          180096       1920
# 10    11              'Supermarket/Grocery Store'           18175       1978
# ...

# %%
from sklearn.preprocessing import StandardScaler
features = ['YearBuilt','ENERGYSTARScore']
# Separating out the features
x = d.loc[:, features].values
# Standardizing the features
x = StandardScaler().fit_transform(x)
x
# Out:
# array([[ 0.72781445, -0.7211403 ],
#        [ 0.48156144, -0.7211403 ],
#        [ 1.22032046, -0.7211403 ],
#        [ 1.27504335, -0.4807602 ],
#        [ 0.61836866,  2.82446619],
#        [-0.36664337,  2.22351593],
#        [ 0.31739277,  0.4807602 ],
#        [-1.37901684, -0.36057015],
#        [-1.98096864, -0.7211403 ],
#        [-1.18748673, -0.2403801 ],
#        [ 0.3994771 ,  0.66104528],
#        [-1.24220962, -0.7211403 ],
#        [-1.18748673, -0.7211403 ],
#        [ 0.18058554, -0.7211403 ],
#        [-1.46110118,  0.90142538],
#        [ 0.67309155, -0.36057015],
#        [ 0.26266987, -0.66104528],
#        [ 0.59100722,  0.12019005],
#        [ 1.0014289 ,  0.66104528],
#        [ 1.05615179, -0.7211403 ]])

# %%
pca = PCA(n_components=2)
principalComponents = pca.fit_transform(x)
principalDf = pd.DataFrame(data = principalComponents
             , columns = ['principal component 1', 'principal component 2'])
principalDf
# Out:
#     principal component 1  principal component 2
# 0                0.004719              -1.024566
# 1               -0.169408              -0.850439
# 2                0.352974              -1.372820
# 3                0.561643              -1.241541
# 4                2.434452               1.559947
# 5                1.313007               1.831519
# 6                0.564379               0.115518
# 7               -1.230074               0.720151
# 8               -1.910680               0.890833
# 9               -1.009654               0.669706
# 10               0.749903               0.184957
# 11              -1.388298               0.368452
# 12              -1.349603               0.329757
# 13              -0.382230              -0.637616
# 14              -0.395751               1.670559
# 15               0.220986              -0.730909
# 16              -0.281694              -0.653165
# 17               0.502892              -0.332918
# ...

# %%
pca.components_
# Out:
# array([[ 0.70710678,  0.70710678],
#        [-0.70710678,  0.70710678]])

# %%
pca.explained_variance_ratio_
# Out:
# array([0.5263497, 0.4736503])

# %%
pca.explained_variance_
# Out:
# array([1.10810462, 0.99715854])
